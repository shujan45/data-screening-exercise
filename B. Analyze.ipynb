# %%
cleaned_df <- read.csv("cleaned_detention.csv",encoding = "latin1")
cleaned_df
# Out:
#     X   Name                                          City            State
# 1    1  ADAMS COUNTY DET CENTER                       NATCHEZ         MS
# 2    2  ADELANTO ICE PROCESSING CENTER                ADELANTO        CA
# 3    3  ALAMANCE COUNTY DETENTION FACILITY            GRAHAM          NC
# 4    4  ALEXANDRIA STAGING FACILITY                   ALEXANDRIA      LA
# 5    5  ALLEGANY COUNTY JAIL                          BELMONT         NY
# 6    6  ALLEN PARISH PUBLIC SAFETY COMPLEX            OBERLIN         LA
# 7    7  ATLANTAÂ USÂ PEN                              ATLANTA         GA
# 8    8  BAKER COUNTY SHERIFF DEPT.                    MACCLENNY       FL
# 9    9  BERLIN FED. CORR. INST.                       BERLIN          NH
# 10  10  BLUEBONNET DETENTION FACILITY                 ANSON           TX
# 11  11  BOONE COUNTY JAIL                             BURLINGTON      KY
# 12  12  BROWARD COUNTY JAIL                           FT.LAUDERDALE   FL
# ...

# %%
cleaned_df$Total_Population <- cleaned_df$Level.A + cleaned_df$Level.B + cleaned_df$Level.C +cleaned_df$Level.D

# %%
cleaned_df
# Out:
#     X   Name                                          City            State
# 1    1  ADAMS COUNTY DET CENTER                       NATCHEZ         MS
# 2    2  ADELANTO ICE PROCESSING CENTER                ADELANTO        CA
# 3    3  ALAMANCE COUNTY DETENTION FACILITY            GRAHAM          NC
# 4    4  ALEXANDRIA STAGING FACILITY                   ALEXANDRIA      LA
# 5    5  ALLEGANY COUNTY JAIL                          BELMONT         NY
# 6    6  ALLEN PARISH PUBLIC SAFETY COMPLEX            OBERLIN         LA
# 7    7  ATLANTAÂ USÂ PEN                              ATLANTA         GA
# 8    8  BAKER COUNTY SHERIFF DEPT.                    MACCLENNY       FL
# 9    9  BERLIN FED. CORR. INST.                       BERLIN          NH
# 10  10  BLUEBONNET DETENTION FACILITY                 ANSON           TX
# 11  11  BOONE COUNTY JAIL                             BURLINGTON      KY
# 12  12  BROWARD COUNTY JAIL                           FT.LAUDERDALE   FL
# ...

# %%
sorted_data <- cleaned_df[order(cleaned_df$Total_Population, decreasing = TRUE), ]
sorted_data
# Out:
#     X   Name                                             City           State
# 1     1 ADAMS COUNTY DET CENTER                          NATCHEZ        MS
# 119 120 SOUTH TEXAS ICE PROCESSING CENTER                PEARSALL       TX
# 122 123 STEWART DETENTION CENTER                         LUMPKIN        GA
# 131 133 WINN CORRECTIONAL CENTER                         WINNFIELD      LA
# 94   94 OTAY MESA DETENTION CENTER                       SAN DIEGO      CA
# 42   42 ELOY FEDERAL CONTRACT FACILITY                   ELOY           AZ
# 84   84 MOSHANNON& VALLEY PROCESSING CENTER              PHILIPSBURG    PA
# 83   83 MONTGOMERY ICE PROCESSING CENTER                 CONROE         TX
# 19   19 CENTRAL LOUISIANA ICE PROCESSING CENTER CLIPC    JENA           LA
# 32   32 DENVER CONTRACT DETENTION FACILITY               AURORA         CO
# 104 104 PORT ISABEL SPC                                  LOS FRESNOS    TX
# ...

# %%
Top_10_Detention_Place <- head(sorted_data,10)
Top_10_Detention_Place
# Out:
#     X   Name                                          City        State
# 1     1 ADAMS COUNTY DET CENTER                       NATCHEZ     MS
# 119 120 SOUTH TEXAS ICE PROCESSING CENTER             PEARSALL    TX
# 122 123 STEWART DETENTION CENTER                      LUMPKIN     GA
# 131 133 WINN CORRECTIONAL CENTER                      WINNFIELD   LA
# 94   94 OTAY MESA DETENTION CENTER                    SAN DIEGO   CA
# 42   42 ELOY FEDERAL CONTRACT FACILITY                ELOY        AZ
# 84   84 MOSHANNON& VALLEY PROCESSING CENTER           PHILIPSBURG PA
# 83   83 MONTGOMERY ICE PROCESSING CENTER              CONROE      TX
# 19   19 CENTRAL LOUISIANA ICE PROCESSING CENTER CLIPC JENA        LA
# 32   32 DENVER CONTRACT DETENTION FACILITY            AURORA      CO
#     Level.A   Level.B   Level.C    Level.D    Last.Inspection.End.Date
# 1   1876.4611 266.43114   6.724551   4.257485 2025-01-16
# 119 1299.0838 106.12575 188.724551  68.197605 2025-02-06
# ...

# %% [raw]
# Above is the dataframe of the top 10 detention place from the provided data.
# We can remove the Level.A and other Levels columns as we have total population column after add them

# %%
# library(dplyr)
# sorted_data <- sorted_data %>%
#   select(-c(Level.A, Level.B, Level.C, Level.D))

# %%
sorted_data
# Out:
#     X   Name                                             City           State
# 1     1 ADAMS COUNTY DET CENTER                          NATCHEZ        MS
# 119 120 SOUTH TEXAS ICE PROCESSING CENTER                PEARSALL       TX
# 122 123 STEWART DETENTION CENTER                         LUMPKIN        GA
# 131 133 WINN CORRECTIONAL CENTER                         WINNFIELD      LA
# 94   94 OTAY MESA DETENTION CENTER                       SAN DIEGO      CA
# 42   42 ELOY FEDERAL CONTRACT FACILITY                   ELOY           AZ
# 84   84 MOSHANNON& VALLEY PROCESSING CENTER              PHILIPSBURG    PA
# 83   83 MONTGOMERY ICE PROCESSING CENTER                 CONROE         TX
# 19   19 CENTRAL LOUISIANA ICE PROCESSING CENTER CLIPC    JENA           LA
# 32   32 DENVER CONTRACT DETENTION FACILITY               AURORA         CO
# 104 104 PORT ISABEL SPC                                  LOS FRESNOS    TX
# ...

# %% [raw]
# So the top 10 Detention Jail in Provided Date is below:

# %%
List=as.list(Top_10_Detention_Place$Name)
List
# Out:
# [[1]]
# [1] "ADAMS COUNTY DET CENTER"
#
# [[2]]
# [1] "SOUTH TEXAS ICE PROCESSING CENTER"
#
# [[3]]
# [1] "STEWART DETENTION CENTER"
#
# [[4]]
# [1] "WINN CORRECTIONAL CENTER"
#
# [[5]]
# [1] "OTAY MESA DETENTION CENTER"
#
# [[6]]
# [1] "ELOY FEDERAL CONTRACT FACILITY"
#
# [[7]]
# [1] "MOSHANNON& VALLEY PROCESSING CENTER"
#
# [[8]]
# [1] "MONTGOMERY ICE PROCESSING CENTER"
#
# [[9]]
# [1] "CENTRAL LOUISIANA ICE PROCESSING CENTER CLIPC"
#
# [[10]]
# [1] "DENVER CONTRACT DETENTION FACILITY"
